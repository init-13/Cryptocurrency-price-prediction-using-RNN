# %%
from ipywidgets import Layout, Button, Box, FloatText, Textarea, Dropdown, Label, IntSlider, interact, fixed
from IPython.display import display
from finalRun import finalOutput
# Out:
# 2022-05-29 20:36:44.585965: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-29 20:36:44.586004: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
form_item_layout = Layout(
    display='flex',
    flex_flow='row',
    justify_content='space-between'
)

# %%
Neurons = Box([Label(value='Neurons'), IntSlider(min=50, max=300, step=50)], layout=form_item_layout)

Epoch = Box([Label(value='Epochs'), IntSlider(min=10, max=50, step=5)], layout=form_item_layout)

Batchsize = Box([Label(value='Batch Size'), IntSlider(min=1, max=100)], layout=form_item_layout)

Optimizer = Box([Label(value='Optimizer'),Dropdown(options=['Adadelta', 'Adagrad' ,'Adam' ,'Adamax' ,'Ftrl' ,'Nadam' ])], layout=form_item_layout)

Lossfunction =  Box([Label(value='Loss Function'), Dropdown(options=['Mean Squared Error (MSE)', 'Mean Absolute Error (MAE)', 'Huber Loss'])], layout=form_item_layout)

# %%
form_items = [ Neurons, Epoch, Batchsize , Optimizer , Lossfunction]

form = Box(form_items, layout=Layout(
    display='flex',
    flex_flow='column',
    border='solid 2px',
    align_items='stretch',
    width='50%'
))

display(form)
# Out:
# Box(children=(Box(children=(Label(value='Neurons'), IntSlider(value=50, max=300, min=50, step=50)), layout=Lay…

# %%
Neurons = IntSlider(min=50, max=300, step=50,description = "Neurons")

Epoch =  IntSlider(min=10, max=50, step=5,description = "Epoch")

Batchsize = IntSlider(min=1, max=100,description = "Batch Size")

Optimizer =Dropdown(options=['Adadelta', 'Adagrad' ,'Adam' ,'Adamax' ,'Ftrl' ,'Nadam' ], description = "Optimizer")

Lossfunction =  Dropdown(options=['Mean Squared Error (MSE)', 'Mean Absolute Error (MAE)', 'Hinge Loss', "Binary Cross Entropy"], description = "Loss Function")

# %%
interact(finalOutput,lstm_neurons = Neurons, epochs = Epoch , batch_size = Batchsize , loss = Lossfunction , optimizer = Optimizer , window_len=fixed(5), test_size=fixed(0.1), zero_base=fixed(True), dropout=fixed(0.2));
# Out:
# interactive(children=(IntSlider(value=50, description='Neurons', max=300, min=50, step=50), IntSlider(value=10…

# %%
finalOutput()
# Out:
# Neurons ->  300
# Epoch ->  50
# Batch Size ->  36
# Loss Function ->  mse
# Optimizer->  adam
# Epoch 1/50
# 50/50 - 2s - loss: 0.0071 - val_loss: 0.0019 - 2s/epoch - 43ms/step
# Epoch 2/50
# 50/50 - 0s - loss: 0.0059 - val_loss: 0.0023 - 375ms/epoch - 7ms/step
# Epoch 3/50
# 50/50 - 0s - loss: 0.0039 - val_loss: 0.0019 - 392ms/epoch - 8ms/step
# Epoch 4/50
# 50/50 - 0s - loss: 0.0034 - val_loss: 0.0014 - 368ms/epoch - 7ms/step
# Epoch 5/50
# 50/50 - 0s - loss: 0.0031 - val_loss: 0.0014 - 378ms/epoch - 8ms/step
# Epoch 6/50
# 50/50 - 0s - loss: 0.0027 - val_loss: 0.0015 - 387ms/epoch - 8ms/step
# Epoch 7/50
# 50/50 - 0s - loss: 0.0025 - val_loss: 0.0013 - 384ms/epoch - 8ms/step
# Epoch 8/50
# 50/50 - 0s - loss: 0.0024 - val_loss: 0.0013 - 392ms/epoch - 8ms/step
# Epoch 9/50
# 50/50 - 0s - loss: 0.0028 - val_loss: 0.0012 - 379ms/epoch - 8ms/step
# Epoch 10/50
# 50/50 - 0s - loss: 0.0028 - val_loss: 0.0012 - 412ms/epoch - 8ms/step
# Epoch 11/50
# 50/50 - 0s - loss: 0.0028 - val_loss: 0.0015 - 415ms/epoch - 8ms/step
# Epoch 12/50
# 50/50 - 0s - loss: 0.0022 - val_loss: 0.0013 - 409ms/epoch - 8ms/step
# Epoch 13/50
# 50/50 - 0s - loss: 0.0022 - val_loss: 0.0012 - 444ms/epoch - 9ms/step
# Epoch 14/50
# 50/50 - 0s - loss: 0.0022 - val_loss: 0.0012 - 394ms/epoch - 8ms/step
# Epoch 15/50
# 50/50 - 0s - loss: 0.0021 - val_loss: 0.0012 - 396ms/epoch - 8ms/step
# Epoch 16/50
# 50/50 - 0s - loss: 0.0021 - val_loss: 0.0012 - 379ms/epoch - 8ms/step
# Epoch 17/50
# 50/50 - 0s - loss: 0.0020 - val_loss: 0.0012 - 379ms/epoch - 8ms/step
# Epoch 18/50
# 50/50 - 0s - loss: 0.0020 - val_loss: 0.0012 - 376ms/epoch - 8ms/step
# Epoch 19/50
# 50/50 - 0s - loss: 0.0022 - val_loss: 0.0012 - 377ms/epoch - 8ms/step
# Epoch 20/50
# 50/50 - 0s - loss: 0.0020 - val_loss: 0.0011 - 377ms/epoch - 8ms/step
# Epoch 21/50
# 50/50 - 0s - loss: 0.0018 - val_loss: 0.0012 - 445ms/epoch - 9ms/step
# Epoch 22/50
# 50/50 - 0s - loss: 0.0019 - val_loss: 0.0012 - 421ms/epoch - 8ms/step
# Epoch 23/50
# 50/50 - 0s - loss: 0.0018 - val_loss: 0.0012 - 406ms/epoch - 8ms/step
# Epoch 24/50
# 50/50 - 0s - loss: 0.0019 - val_loss: 0.0012 - 412ms/epoch - 8ms/step
# Epoch 25/50
# 50/50 - 0s - loss: 0.0020 - val_loss: 0.0011 - 419ms/epoch - 8ms/step
# Epoch 26/50
# 50/50 - 0s - loss: 0.0019 - val_loss: 0.0012 - 404ms/epoch - 8ms/step
# Epoch 27/50
# 50/50 - 0s - loss: 0.0020 - val_loss: 0.0012 - 395ms/epoch - 8ms/step
# Epoch 28/50
# 50/50 - 0s - loss: 0.0021 - val_loss: 0.0011 - 395ms/epoch - 8ms/step
# Epoch 29/50
# 50/50 - 0s - loss: 0.0019 - val_loss: 0.0014 - 393ms/epoch - 8ms/step
# Epoch 30/50
# 50/50 - 0s - loss: 0.0018 - val_loss: 0.0011 - 408ms/epoch - 8ms/step
# Epoch 31/50
# 50/50 - 0s - loss: 0.0018 - val_loss: 0.0012 - 392ms/epoch - 8ms/step
# Epoch 32/50
# 50/50 - 0s - loss: 0.0019 - val_loss: 0.0013 - 419ms/epoch - 8ms/step
# Epoch 33/50
# 50/50 - 0s - loss: 0.0018 - val_loss: 0.0013 - 376ms/epoch - 8ms/step
# Epoch 34/50
# 50/50 - 0s - loss: 0.0021 - val_loss: 0.0011 - 393ms/epoch - 8ms/step
# Epoch 35/50
# 50/50 - 0s - loss: 0.0017 - val_loss: 0.0012 - 422ms/epoch - 8ms/step
# Epoch 36/50
# 50/50 - 0s - loss: 0.0017 - val_loss: 0.0011 - 409ms/epoch - 8ms/step
# Epoch 37/50
# 50/50 - 0s - loss: 0.0018 - val_loss: 0.0011 - 397ms/epoch - 8ms/step
# Epoch 38/50
# 50/50 - 0s - loss: 0.0018 - val_loss: 0.0012 - 408ms/epoch - 8ms/step
# Epoch 39/50
# 50/50 - 0s - loss: 0.0018 - val_loss: 0.0011 - 421ms/epoch - 8ms/step
# Epoch 40/50
# 50/50 - 0s - loss: 0.0018 - val_loss: 0.0013 - 383ms/epoch - 8ms/step
# Epoch 41/50
# 50/50 - 0s - loss: 0.0019 - val_loss: 0.0011 - 368ms/epoch - 7ms/step
# Epoch 42/50
# 50/50 - 0s - loss: 0.0021 - val_loss: 0.0011 - 379ms/epoch - 8ms/step
# Epoch 43/50
# 50/50 - 0s - loss: 0.0026 - val_loss: 0.0011 - 385ms/epoch - 8ms/step
# Epoch 44/50
# 50/50 - 0s - loss: 0.0023 - val_loss: 0.0011 - 381ms/epoch - 8ms/step
# Epoch 45/50
# 50/50 - 0s - loss: 0.0021 - val_loss: 0.0012 - 401ms/epoch - 8ms/step
# Epoch 46/50
# 50/50 - 0s - loss: 0.0018 - val_loss: 0.0011 - 394ms/epoch - 8ms/step
# Epoch 47/50
# 50/50 - 0s - loss: 0.0019 - val_loss: 0.0012 - 378ms/epoch - 8ms/step
# Epoch 48/50
# 50/50 - 0s - loss: 0.0018 - val_loss: 0.0012 - 394ms/epoch - 8ms/step
# Epoch 49/50
# 50/50 - 0s - loss: 0.0018 - val_loss: 0.0012 - 401ms/epoch - 8ms/step
# Epoch 50/50
# 50/50 - 0s - loss: 0.0018 - val_loss: 0.0012 - 399ms/epoch - 8ms/step
# 7/7 [==============================] - 0s 3ms/step
